# %% [markdown]
# <a href="https://colab.research.google.com/github/ShrihariJalihal/DL-Assignments/blob/develop/assignment_230701/M1_AST_05_Numerical_Optimization_C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Advanced Programme in Deep Learning (Foundations and Applications)
# ## A Program by IISc and TalentSprint
# ### Assignment 5: Numerical Optimization

# %% [markdown]
# ## Learning Objectives

# %% [markdown]
# At the end of the assignment, you will be able to
#
# * Understanding local and global minima
# * Interpreting the criteria to find global minima and local minima
# * Implement gradient descent and understanding its convergence process

# %% [markdown]
# ### Setup Steps:

# %%
#@title Please enter your registration id to start: { run: "auto", display-mode: "form" }
Id = "2240589" #@param {type:"string"}

# %%
#@title Please enter your password (normally your phone number) to continue: { run: "auto", display-mode: "form" }
password = "9886499911" #@param {type:"string"}

# %%
#@title Run this cell to complete the setup for this Notebook
from IPython import get_ipython
import warnings
warnings.filterwarnings("ignore")

ipython = get_ipython()

notebook= "M1_AST_05_Numerical_Optimization_C" #name of the notebook

def setup():
    from IPython.display import HTML, display
    display(HTML('<script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId={0}&recordId={1}"></script>'.format(getId(),submission_id)))
    print("Setup completed successfully")
    return

def submit_notebook():
    ipython.magic("notebook -e "+ notebook + ".ipynb")

    import requests, json, base64, datetime

    url = "https://dashboard.talentsprint.com/xp/app/save_notebook_attempts"
    if not submission_id:
      data = {"id" : getId(), "notebook" : notebook, "mobile" : getPassword()}
      r = requests.post(url, data = data)
      r = json.loads(r.text)

      if r["status"] == "Success":
          return r["record_id"]
      elif "err" in r:
        print(r["err"])
        return None
      else:
        print ("Something is wrong, the notebook will not be submitted for grading")
        return None

    elif getAnswer1() and getAnswer2() and getComplexity() and getAdditional() and getConcepts() and getComments() and getMentorSupport():
      f = open(notebook + ".ipynb", "rb")
      file_hash = base64.b64encode(f.read())

      data = {"complexity" : Complexity, "additional" :Additional,
              "concepts" : Concepts, "record_id" : submission_id,
              "answer1" : Answer1, "answer2" : Answer2, "id" : Id, "file_hash" : file_hash,
              "notebook" : notebook,
              "feedback_experiments_input" : Comments,
              "feedback_mentor_support": Mentor_support}
      r = requests.post(url, data = data)
      r = json.loads(r.text)
      if "err" in r:
        print(r["err"])
        return None
      else:
        print("Your submission is successful.")
        print("Ref Id:", submission_id)
        print("Date of submission: ", r["date"])
        print("Time of submission: ", r["time"])
        print("View your submissions: https://dlfa-iisc.talentsprint.com/notebook_submissions")
        #print("For any queries/discrepancies, please connect with mentors through the chat icon in LMS dashboard.")
        return submission_id
    else: submission_id


def getAdditional():
  try:
    if not Additional:
      raise NameError
    else:
      return Additional
  except NameError:
    print ("Please answer Additional Question")
    return None

def getComplexity():
  try:
    if not Complexity:
      raise NameError
    else:
      return Complexity
  except NameError:
    print ("Please answer Complexity Question")
    return None

def getConcepts():
  try:
    if not Concepts:
      raise NameError
    else:
      return Concepts
  except NameError:
    print ("Please answer Concepts Question")
    return None


# def getWalkthrough():
#   try:
#     if not Walkthrough:
#       raise NameError
#     else:
#       return Walkthrough
#   except NameError:
#     print ("Please answer Walkthrough Question")
#     return None

def getComments():
  try:
    if not Comments:
      raise NameError
    else:
      return Comments
  except NameError:
    print ("Please answer Comments Question")
    return None


def getMentorSupport():
  try:
    if not Mentor_support:
      raise NameError
    else:
      return Mentor_support
  except NameError:
    print ("Please answer Mentor support Question")
    return None

def getAnswer1():
  try:
    if not Answer1:
      raise NameError
    else:
      return Answer1
  except NameError:
    print ("Please answer Question 1")
    return None

def getAnswer2():
  try:
    if not Answer2:
      raise NameError
    else:
      return Answer2
  except NameError:
    print ("Please answer Question 2")
    return None


def getId():
  try:
    return Id if Id else None
  except NameError:
    return None

def getPassword():
  try:
    return password if password else None
  except NameError:
    return None

submission_id = None
### Setup
if getPassword() and getId():
  submission_id = submit_notebook()
  if submission_id:
    setup()
else:
  print ("Please complete Id and Password cells before running setup")
# Out:
# <script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId=2240589&recordId=548"></script>
# Setup completed successfully

# %% [markdown]
# ### Import the required Packages

# %%
import pandas as pd
import numpy as np
import random
import pdb
from matplotlib import pyplot as plt

# %% [markdown]
# 1. Given the following quadratic function: $x^{2} - 2x + 1$, verify the necessary and sufficient conditions for global minima.

# %%
# Convex unimodal optimization function

# Objective function
def objective(x):
	return x**2.0 - 2*x + 1

# Define range for input
r_min, r_max = -10.0, 10.0

# Sample input range uniformly at 0.1 increments
inputs = np.arange(r_min, r_max, 0.1)

# Compute targets
results = objective(inputs)

# %%
# Create a line plot of input vs result
plt.plot(inputs, results)

# Define optimal input value
x_optima = 1.0       # Provide the value you found out

# Draw a vertical line at the optimal input
plt.axvline(x=x_optima, ls='--', color='red')

# Show the plot
plt.show()

# %% [markdown]
# 2. Given the following cubic function: $x^{3} - 9x^{2} - 48x + 52$, verify the necessary and sufficient conditions for local minima and maxima in the closed interval [−10, 20].

# %%
# Non-convex unimodal optimization function

# Objective function
def objective(x):
	return x**3 - 9*x**2 - 48*x + 52

# Define range for input
r_min, r_max = -10.0, 20.0

# Sample input range uniformly at 0.1 increments
inputs = np.arange(r_min, r_max, 0.1)

# Compute targets
results = objective(inputs)

# %%
# Create a line plot of input vs result
plt.plot(inputs, results)

# Define optimal input value
x_optima = -2       # Provide the value you found out here

# Draw a vertical line at the optimal input
plt.axvline(x=x_optima, ls='--', color='red')

# Show the plot
plt.show()

# %% [markdown]
# ### Gradient Descent
#
# Gradient descent is an optimization algorithm used to find the values of parameters (coefficients) of a function that minimizes a **cost function**.
#
# It is used while training a machine learning model. It is an optimization algorithm, based on  first order gradients, that tweaks it’s parameters iteratively to minimize a given function to its local minimum and global minima if the function is convex.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Further, a **cost function** is a measure of how wrong the model is in terms of its ability to estimate the relationship between X and y. This is typically expressed as a difference or distance between the predicted value and the actual value.

# %% [markdown]
# To learn more about Gradient Descent click [here](https://towardsdatascience.com/implement-gradient-descent-in-python-9b93ed7108d1)

# %% [markdown]
# 3. Find the global minima of the function $y=x^{2} - 2x + 1$ starting from the point x=3.

# %% [markdown]
# Initializing the parameters

# %%
# The algorithm starts at x=3
cur_x = 3

# Learning rate
rate = 0.01

# This tells us when to stop the algorithm
precision = 0.0000000001
previous_step_size = 1

# Maximum number of iterations
max_iters = 1000

# Iteration counter
iters = 0

# Gradient of our function
f = lambda x : x**2 - 2*x + 1
df = lambda x : 2*x - 2

# %% [markdown]
# Run a loop to perform gradient descent. Stop the loop when difference between x values from 2 consecutive iterations is less than 0.0000000001 or when number of iterations exceeds 1000.

# %%
# Declaring y_m and x_m for storing the values of f(cur_x) and cur_x
y_m = []
x_m = []

while previous_step_size > precision and iters < max_iters:
    # Store current x value in prev_x
    x_m.append(cur_x)
    y_m.append(f(cur_x))
    prev_x = cur_x

    # Gradient descent
    cur_x = cur_x - rate * df(prev_x)

    # Change in x
    previous_step_size = abs(cur_x - prev_x)

    # Iteration count
    iters = iters+1

    # Print iterations
    print("Iteration",iters,"\nX value is",cur_x)

print("The global minimum occurs at", cur_x)
# Out:
# Iteration 1
# X value is 2.96
# Iteration 2
# X value is 2.9208
# Iteration 3
# X value is 2.882384
# Iteration 4
# X value is 2.84473632
# Iteration 5
# X value is 2.8078415936
# Iteration 6
# X value is 2.7716847617280003
# Iteration 7
# X value is 2.7362510664934403
# Iteration 8
# X value is 2.7015260451635714
# Iteration 9
# X value is 2.6674955242603
# Iteration 10
# X value is 2.6341456137750936
# Iteration 11
# X value is 2.601462701499592
# Iteration 12
# X value is 2.5694334474696
# Iteration 13
# X value is 2.538044778520208
# Iteration 14
# X value is 2.507283882949804
# Iteration 15
# X value is 2.477138205290808
# Iteration 16
# X value is 2.447595441184992
# Iteration 17
# X value is 2.418643532361292
# Iteration 18
# X value is 2.390270661714066
# Iteration 19
# X value is 2.3624652484797846
# Iteration 20
# X value is 2.335215943510189
# Iteration 21
# X value is 2.3085116246399853
# Iteration 22
# X value is 2.2823413921471856
# Iteration 23
# X value is 2.256694564304242
# Iteration 24
# X value is 2.231560673018157
# Iteration 25
# X value is 2.206929459557794
# Iteration 26
# X value is 2.182790870366638
# Iteration 27
# X value is 2.1591350529593054
# Iteration 28
# X value is 2.1359523519001193
# Iteration 29
# X value is 2.113233304862117
# Iteration 30
# X value is 2.0909686387648745
# Iteration 31
# X value is 2.069149265989577
# Iteration 32
# X value is 2.0477662806697854
# Iteration 33
# X value is 2.0268109550563898
# Iteration 34
# X value is 2.006274735955262
# Iteration 35
# X value is 1.9861492412361568
# Iteration 36
# X value is 1.9664262564114336
# Iteration 37
# X value is 1.947097731283205
# Iteration 38
# X value is 1.9281557766575408
# Iteration 39
# X value is 1.90959266112439
# Iteration 40
# X value is 1.8914008079019022
# Iteration 41
# X value is 1.8735727917438643
# Iteration 42
# X value is 1.856101335908987
# Iteration 43
# X value is 1.8389793091908073
# Iteration 44
# X value is 1.822199723006991
# Iteration 45
# X value is 1.8057557285468513
# Iteration 46
# X value is 1.7896406139759142
# Iteration 47
# X value is 1.7738478016963959
# Iteration 48
# X value is 1.758370845662468
# Iteration 49
# X value is 1.7432034287492186
# Iteration 50
# X value is 1.7283393601742343
# Iteration 51
# X value is 1.7137725729707496
# Iteration 52
# X value is 1.6994971215113346
# Iteration 53
# X value is 1.6855071790811078
# Iteration 54
# X value is 1.6717970354994856
# Iteration 55
# X value is 1.6583610947894958
# Iteration 56
# X value is 1.6451938728937059
# Iteration 57
# X value is 1.6322899954358319
# Iteration 58
# X value is 1.6196441955271152
# Iteration 59
# X value is 1.607251311616573
# Iteration 920
# X value is 1.0000000169441436
# Iteration 921
# X value is 1.0000000166052607
# Iteration 922
# X value is 1.0000000162731555
# Iteration 923
# X value is 1.0000000159476923
# Iteration 924
# X value is 1.0000000156287385
# Iteration 925
# X value is 1.0000000153161637
# Iteration 926
# X value is 1.0000000150098405
# Iteration 927
# X value is 1.0000000147096437
# Iteration 928
# X value is 1.0000000144154508
# Iteration 929
# X value is 1.000000014127142
# Iteration 930
# X value is 1.000000013844599
# Iteration 931
# X value is 1.000000013567707
# Iteration 932
# X value is 1.000000013296353
# Iteration 933
# X value is 1.0000000130304258
# Iteration 934
# X value is 1.0000000127698174
# Iteration 935
# X value is 1.000000012514421
# Iteration 936
# X value is 1.0000000122641326
# Iteration 937
# X value is 1.00000001201885
# Iteration 938
# X value is 1.0000000117784729
# Iteration 939
# X value is 1.0000000115429033
# Iteration 940
# X value is 1.0000000113120453
# Iteration 941
# X value is 1.0000000110858045
# Iteration 942
# X value is 1.0000000108640883
# Iteration 943
# X value is 1.0000000106468065
# Iteration 944
# X value is 1.0000000104338704
# Iteration 945
# X value is 1.0000000102251931
# Iteration 946
# X value is 1.0000000100206892
# Iteration 947
# X value is 1.0000000098202755
# Iteration 948
# X value is 1.00000000962387
# Iteration 949
# X value is 1.0000000094313926
# Iteration 950
# X value is 1.0000000092427648
# Iteration 951
# X value is 1.0000000090579095
# Iteration 952
# X value is 1.0000000088767513
# Iteration 953
# X value is 1.0000000086992162
# Iteration 954
# X value is 1.0000000085252319
# Iteration 955
# X value is 1.0000000083547271
# Iteration 956
# X value is 1.0000000081876326
# Iteration 957
# X value is 1.00000000802388
# Iteration 958
# X value is 1.0000000078634024
# Iteration 959
# X value is 1.0000000077061344
# Iteration 960
# X value is 1.0000000075520117
# Iteration 961
# X value is 1.0000000074009714
# Iteration 962
# X value is 1.000000007252952
# Iteration 963
# X value is 1.000000007107893
# Iteration 964
# X value is 1.000000006965735
# Iteration 965
# X value is 1.0000000068264203
# Iteration 966
# X value is 1.000000006689892
# Iteration 967
# X value is 1.0000000065560941
# Iteration 968
# X value is 1.0000000064249723
# Iteration 969
# X value is 1.000000006296473
# Iteration 970
# X value is 1.0000000061705434
# Iteration 971
# X value is 1.0000000060471326
# Iteration 972
# X value is 1.00000000592619
# Iteration 973
# X value is 1.0000000058076661
# Iteration 974
# X value is 1.0000000056915128
# Iteration 975
# X value is 1.0000000055776825
# Iteration 976
# X value is 1.0000000054661289
# Iteration 977
# X value is 1.0000000053568063
# Iteration 978
# X value is 1.0000000052496703
# Iteration 979
# X value is 1.000000005144677
# Iteration 980
# X value is 1.0000000050417834
# Iteration 981
# X value is 1.0000000049409479
# Iteration 982
# X value is 1.000000004842129
# The global minimum occurs at 1.000000004842129

# %% [markdown]
# Plotting the graph

# %%
Xs = np.linspace(-60, 50, 100)
ys = f(Xs)
plt.plot(Xs, ys)

# Plotting the graph for x_m and y_m
plt.plot(x_m, y_m)
plt.grid(True)
plt.xticks(np.arange(-60, 50, 10));

# %% [markdown]
# The algorithm runs for 982 iterations before it terminates and the global minimum accurs at 1.000000004842129

# %% [markdown]
# 4. Find the local minima of the function $y=x^{3} - 9x^{2} -48x + 52$ starting from the point x = 10

# %% [markdown]
# Initializing the parameters

# %%
# The algorithm starts at x=3
cur_x = 10

# Learning rate
rate = 0.01

# This tells us when to stop the algorithm
precision = 0.0000000001
previous_step_size = 1

# Maximum number of iterations
max_iters = 1000

# Iteration counter
iters = 0

# Gradient of our function
f = lambda x: x**3 - 9*x**2 - 48*x + 52
df = lambda x: 3*x**2 - 18*x - 48

# %% [markdown]
# Run a loop to perform gradient descent. Stop the loop when difference between x values from 2 consecutive iterations is less than 0.0000000001 or when number of iterations exceeds 1000.

# %%
# Declaring y_m and x_m for storing the values of f(cur_x) and cur_x
y_m = []
x_m = []

while previous_step_size > precision and iters < max_iters:
    # Store current x value in prev_x
    x_m.append(cur_x)
    y_m.append(f(cur_x))
    prev_x = cur_x

    # Gradient descent
    cur_x = cur_x - rate * df(prev_x)

    # Change in x
    previous_step_size = abs(cur_x - prev_x)

    # Iteration count
    iters = iters+1

    # Print iterations
    print("Iteration",iters,"\nX value is",cur_x)

print("The local minimum occurs at", cur_x)
# Out:
# Iteration 1
# X value is 9.28
# Iteration 2
# X value is 8.846848
# Iteration 3
# X value is 8.57127905394688
# Iteration 4
# X value is 8.390104545038463
# Iteration 5
# X value is 8.268507734845135
# Iteration 6
# X value is 8.185792522281444
# Iteration 7
# X value is 8.12901919975694
# Iteration 8
# X value is 8.08981406121268
# Iteration 9
# X value is 8.06262784588113
# Iteration 10
# X value is 8.043721824704399
# Iteration 11
# X value is 8.030547929354414
# Iteration 12
# X value is 8.021355555268455
# Iteration 13
# X value is 8.014935206895693
# Iteration 14
# X value is 8.010447953014834
# Iteration 15
# X value is 8.007310292318717
# Iteration 16
# X value is 8.00511560141189
# Iteration 17
# X value is 8.003580135906988
# Iteration 18
# X value is 8.002505710613699
# Iteration 19
# X value is 8.001753809072019
# Iteration 20
# X value is 8.001227574075026
# Iteration 21
# X value is 8.000859256644375
# Iteration 22
# X value is 8.000601457501404
# Iteration 23
# X value is 8.00042100939845
# Iteration 24
# X value is 8.000294701261447
# Iteration 25
# X value is 8.000206288277548
# Iteration 26
# X value is 8.000144400517637
# Iteration 27
# X value is 8.000101079736801
# Iteration 28
# X value is 8.000070755509247
# Iteration 29
# X value is 8.000049528706283
# Iteration 30
# X value is 8.000034670020806
# Iteration 31
# X value is 8.000024268978503
# Iteration 32
# X value is 8.000016988267284
# Iteration 33
# X value is 8.00001189177844
# Iteration 34
# X value is 8.000008324240666
# Iteration 35
# X value is 8.000005826966387
# Iteration 36
# X value is 8.000004078875453
# Iteration 37
# X value is 8.000002855212317
# Iteration 38
# X value is 8.000001998648377
# Iteration 39
# X value is 8.000001399053744
# Iteration 40
# X value is 8.000000979337562
# Iteration 41
# X value is 8.000000685536264
# Iteration 42
# X value is 8.000000479875371
# Iteration 43
# X value is 8.000000335912754
# Iteration 44
# X value is 8.000000235138923
# Iteration 45
# X value is 8.000000164597244
# Iteration 46
# X value is 8.00000011521807
# Iteration 47
# X value is 8.000000080652649
# Iteration 48
# X value is 8.000000056456855
# Iteration 49
# X value is 8.000000039519799
# Iteration 50
# X value is 8.000000027663859
# Iteration 51
# X value is 8.000000019364702
# Iteration 52
# X value is 8.000000013555292
# Iteration 53
# X value is 8.000000009488705
# Iteration 54
# X value is 8.000000006642093
# Iteration 55
# X value is 8.000000004649465
# Iteration 56
# X value is 8.000000003254625
# Iteration 57
# X value is 8.000000002278238
# Iteration 58
# X value is 8.000000001594767
# Iteration 59
# X value is 8.000000001116337
# Iteration 60
# X value is 8.000000000781435
# Iteration 61
# X value is 8.000000000547004
# Iteration 62
# X value is 8.000000000382903
# Iteration 63
# X value is 8.000000000268031
# Iteration 64
# X value is 8.000000000187622
# The local minimum occurs at 8.000000000187622

# %% [markdown]
# Plotting the graph

# %%
Xs = np.linspace(-20, 20, 100)
ys = f(Xs)
plt.plot(Xs, ys)

# Plotting the graph for x_m and y_m
plt.plot(x_m, y_m)
plt.grid(True)
plt.xticks(np.arange(-20, 20, 1));

# %% [markdown]
# ### Please answer the questions below to complete the experiment:

# %% [markdown]
# Given the function $f(x,y) = x^{2}-2y^{2}-4y+6$, answer the Q.1.

# %%
#@title Q.1. Determine the gradient of the function f(x,y) at (0,1). { run: "auto", form-width: "500px", display-mode: "form" }
Answer1 = "0i-8j" #@param ["","i-4j", "0i+0j", "2i-8j", "0i-8j"]

# %% [markdown]
# Given the function $F(x,y) = x^2 + y^2$, answer the Q.2

# %%
#@title Q.2. Inspect the function F(x,y) and find any maxima or minima. Can you tell whether they are global or local? (Hint : Check the necessary and sufficient conditions by computing the Hessian. ) { run: "auto", form-width: "500px", display-mode: "form" }
Answer2 = "F(x, y) has a Global Minima = 0 at (0, 0)" #@param ["","F(x, y) has a Global Maxima = 0 at (0, 0)", "F(x, y) has a Local Maxima = 0 at (0, 0)", "F(x, y) has a Global Minima = 0 at (0, 0)", "F(x, y) has a Local Minima = 0 at (0, 0)"]

# %%
#@title How was the experiment? { run: "auto", form-width: "500px", display-mode: "form" }
Complexity = "Good and Challenging for me" #@param ["","Too Simple, I am wasting time", "Good, But Not Challenging for me", "Good and Challenging for me", "Was Tough, but I did it", "Too Difficult for me"]

# %%
#@title If it was too easy, what more would you have liked to be added? If it was very difficult, what would you have liked to have been removed? { run: "auto", display-mode: "form" }
Additional = "na" #@param {type:"string"}

# %%
#@title Can you identify the concepts from the lecture which this experiment covered? { run: "auto", vertical-output: true, display-mode: "form" }
Concepts = "Yes" #@param ["","Yes", "No"]

# %%
#@title  Text and image description/explanation and code comments within the experiment: { run: "auto", vertical-output: true, display-mode: "form" }
Comments = "Very Useful" #@param ["","Very Useful", "Somewhat Useful", "Not Useful", "Didn't use"]

# %%
#@title Mentor Support: { run: "auto", vertical-output: true, display-mode: "form" }
Mentor_support = "Very Useful" #@param ["","Very Useful", "Somewhat Useful", "Not Useful", "Didn't use"]

# %%
#@title Run this cell to submit your notebook for grading { vertical-output: true }
try:
  if submission_id:
      return_id = submit_notebook()
      if return_id : submission_id = return_id
  else:
      print("Please complete the setup first.")
except NameError:
  print ("Please complete the setup first.")
# Out:
# Your submission is successful.
# Ref Id: 548
# Date of submission:  02 Jul 2023
# Time of submission:  18:05:46
# View your submissions: https://dlfa-iisc.talentsprint.com/notebook_submissions
